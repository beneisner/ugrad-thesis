# %%
# %load_ext autoreload
# %autoreload 2

# %%
import tensorflow as tf
import alignment as al
import numpy as np
import tifffile as tiff
import math

import PIL.Image
from cStringIO import StringIO
import IPython.display
import numpy as np
def showarray(a, fmt='png'):
    a = np.uint8(a)
    f = StringIO()
    PIL.Image.fromarray(a).save(f, fmt)
    IPython.display.display(IPython.display.Image(data=f.getvalue()))
# Out:
# Segascorus is not installed. Please install by going to trace/trace/thirdparty/segascorus and run 'make'. If this fails, segascorus is likely not compatible with your computer (i.e. Macs).

# %%
# Expand along the channel dimension
train_stack = np.expand_dims(tiff.imread('./isbi/train-input.tif'), axis=3) / 255.0

# %%
tf.reset_default_graph()

# %%
rot = False
max_angle = math.pi/10
trans = True
max_shift = 10

lsamp = al.LocalizationSampler(train_stack, rotation_aug=rot, max_angle=max_angle, translation_aug=trans,
                               max_shift=max_shift)

# %%
with tf.Session() as sess:
    ref_op, sec_op, true_sec_op, true_th =lsamp.get_sample_funcs()
    
    ref, sec, tsec, tth = sess.run([ref_op, sec_op, true_sec_op, true_th])
    showarray(np.squeeze(ref) * 255)
    showarray(np.squeeze(sec) * 255)
    showarray(np.squeeze(tsec) * 255)
    print(tth)
# Out:
# [1.0, -0.0, 9.0, 0.0, 1.0, 3.0]

# %%
showarray(np.squeeze(sec) * 255)

# %%
with tf.Session() as sess:
    ref_op, sec_op, true_sec_op = lsamp.get_sample_funcs()
    
    ref_op = tf.cast(ref_op, dtype=tf.float32) / 255.0
    sec_op = tf.cast(sec_op, dtype=tf.float32) / 255.0
    true_sec_op = tf.cast(true_sec_op, dtype=tf.float32) / 255.0
    
    print(ref_op.get_shape())
    print(sec_op.get_shape())
    print(true_sec_op.get_shape())
    
    aff_trans = al.AffineSpatialTransformer(774)
    
    trans_op = aff_trans(ref_op, sec_op)
#     tf_padded = tf.constant(padded / 255.0, dtype=tf.float32)
#     trans2 = al.transformer_layer(tf_padded, mode='AFFINE')
    # afftrans = al.AffineSpatialTransformer()
    sess.run(tf.global_variables_initializer())
#     res = sess.run(trans2)
    res, ref, sec, tsec = sess.run([trans_op, ref_op, sec_op, true_sec_op])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-faa22c56a8b5> in <module>()
#       1 with tf.Session() as sess:
# ----> 2     ref_op, sec_op, true_sec_op = lsamp.get_sample_funcs()
#       3
#       4     ref_op = tf.cast(ref_op, dtype=tf.float32) / 255.0
#       5     sec_op = tf.cast(sec_op, dtype=tf.float32) / 255.0
#
# ValueError: too many values to unpack

# %%
res.shape
# Out:
# (774, 774)

# %%
showarray(res[:,:]*255)

# %%
showarray(sec[0,:,:,0] * 255)

# %%
tf.reset_default_graph()
train_stack = np.expand_dims(tiff.imread('./isbi/train-input.tif'), axis=3) / 255.0
dim = int(train_stack.shape[1] * (math.sqrt(2)) + 100)
aff_trans = al.AffineSpatialTransformer(dim)
trainer = al.LocalizationTrainer(aff_trans, './realignment/spatial_transformer/affine/test/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-275bf2089ca8> in <module>()
# ----> 1 tf.reset_default_graph()
#       2 train_stack = np.expand_dims(tiff.imread('./isbi/train-input.tif'), axis=3) / 255.0
#       3 dim = int(train_stack.shape[1] * (math.sqrt(2)) + 100)
#       4 aff_trans = al.AffineSpatialTransformer(dim)
#       5 trainer = al.LocalizationTrainer(aff_trans, './realignment/spatial_transformer/affine/test/')
#
# NameError: name 'tf' is not defined

# %%
with tf.Session() as sess:
    trainer.train(sess, train_stack, 101)
# Out:
# (1, 2, 412, 412, 24)
# (1, 2, 206, 206, 36)
# (1, 2, 103, 103, 48)
# (1, 2, 52, 52, 64)
# WARNING:tensorflow:From alignment.py:443: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# WARNING:tensorflow:From alignment.py:443: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Step 0
# Computed images
# Model saved in ./realignment/spatial_transformer/affine/test/model.ckpt
# Step 10
# Step 20
# Step 30
# Step 40
# Step 50
# Step 60
# Step 70
# Step 80
# Step 90
# Step 100
# Computed images

# %%
import download_data as dd

# %%
dd.maybe_create_all_datasets('../../ugrad-thesis/code/', 0.9)
# Out:
# ../../ugrad-thesis/code/cremi/a/train-full.hdf Does not exist
# downloading https://cremi.org/static/data/sample_A_20160501.hdf
# ../../ugrad-thesis/code/cremi/a/test.hdf Does not exist
# downloading https://cremi.org/static/data/sample_A%2B_20160601.hdf
# ../../ugrad-thesis/code/cremi/b/train-full.hdf Does not exist
# downloading https://cremi.org/static/data/sample_B_20160501.hdf
# ../../ugrad-thesis/code/cremi/b/test.hdf Does not exist
# downloading https://cremi.org/static/data/sample_B%2B_20160601.hdf
# ../../ugrad-thesis/code/cremi/c/train-full.hdf Does not exist
# downloading https://cremi.org/static/data/sample_C_20160501.hdf
# ../../ugrad-thesis/code/cremi/c/test.hdf Does not exist
# downloading https://cremi.org/static/data/sample_C%2B_20160601.hdf
